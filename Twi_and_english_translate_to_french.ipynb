# %% [markdown]
# <a href="https://colab.research.google.com/github/gyasifred/msc-thesis/blob/main/Twi_and_english_translate_to_french.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install googletrans==3.1.0a0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 61.8 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 65 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.3 MB/s
# ...
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16367 sha256=0244cd97855767b60d8402a5f5ae02ed9b7a44d64d3b6f2c384d8a45499ce315
#   Stored in directory: /root/.cache/pip/wheels/0c/be/fe/93a6a40ffe386e16089e44dad9018ebab9dc4cb9eb7eab65ae
# Successfully built googletrans
# ...

# %%
# import libraries
import pandas as pd
from googletrans import Translator, constants
from pprint import pprint
import numpy as np

# %%
data = pd.read_csv("/content/verified_data.csv")
data.head()
# Out:
#                                              English  \
# 0  What she lacks in charisma she makes up for wi...
# 1             There was nothing I could do about it.
# 2            Kwaku saw John and Abena holding hands.
# 3                            Can you stay till 2:30?
# 4                         You haven't got much time.
#
#                                          Akuapem Twi
# 0        Nea onni ho adwempa no de adwumaden na ɛba.
# 1                   Na biribiara nni hɛ a metumi ayɔ
# 2      Kwaku hui se  John ne Abena kurakura wɛn nsa.
# 3  So wubetumi atena ha akosi nnɛnmienu npaamu ad...
# 4                                         Wonni mmre

# %%
np.savetxt(r'twi.txt', data['Akuapem Twi'].values, fmt='%s')

# %%
# initiate translator object
translator = Translator()

# %%
# print all available languages
print("Total supported languages:", len(constants.LANGUAGES))
print("Languages:")
pprint(constants.LANGUAGES)

# %%
# translate one english setence to french
sentences = data.English[0]
translator.translate(sentences,dest='fr').text

# %%
# translate the dataframe
#data['ENG_French'] = data['English'].apply(lambda x:translator.translate(x,dest='fr').text)

# %%
data.to_excel("verified_data.xlsx")

# %%
# !pip install transformers[sentencepiece]
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 35.5 MB/s
# ...
#      |████████████████████████████████| 120 kB 74.0 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 53.4 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 64.0 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 880 kB 28.4 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=b29eab5f7c7efff804289596903022d5d0db0aa004634a993885ef78e6c17c45
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...

# %%
from transformers import TFAutoModelForSeq2SeqLM, AutoTokenizer
import torch

# %%
model = TFAutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-tw-fr", from_pt=True)
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-tw-fr")
# Out:
# ...
# All PyTorch model weights were used when initializing TFMarianMTModel.
#
# All the weights of TFMarianMTModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFMarianMTModel for predictions without further training.
# ...

# %%
def translate_twi_fr(text):
  inputs = tokenizer(text,return_tensors="tf")
  outputs = model.generate(inputs["input_ids"], max_length=40, num_beams=4, early_stopping=True)
  return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
data2=data[:10000]

# %%
# translate twi to french
data2['Twi_French'] = data2['Akuapem Twi'].apply(lambda x:translate_twi_fr(x))

# %%
data2.to_excel("/content/drive/MyDrive/verified_data-1-10000.xlsx")
